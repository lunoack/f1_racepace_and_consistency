# %%
import fastf1
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Rookie-Performance

# %%
def setup_fastf1():
    fastf1.Cache.enable_cache('/home/luca/.fastf1/cache')
    fastf1.plotting.setup_mpl()

# %%
setup_fastf1()
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 setup_fastf1()
#
# Cell In[11], line 2, in setup_fastf1()
#       1 def setup_fastf1():
# ----> 2     fastf1.Cache.enable_cache('/home/luca/.fastf1/cache')
#       3     fastf1.plotting.setup_mpl()
#
# File ~/repos/f1_racepace_and_consistency/.venv/lib/python3.13/site-packages/fastf1/req.py:240, in Cache.enable_cache(cls, cache_dir, ignore_version, force_renew, use_requests_cache)
#     237 cache_dir = os.path.expanduser(cache_dir)
#     239 if not os.path.exists(cache_dir):
# --> 240     raise NotADirectoryError("Cache directory does not exist! Please "
#     241                              "check for typos or create it first.")
#     242 cls._CACHE_DIR = cache_dir
#     243 cls._IGNORE_VERSION = ignore_version
#
# ...

# %% [markdown]
# # 2. Constructures: Consistency beats Pace

# %%
# % with both cars classified

# %%
# pit stop errors

# %%
# grid panalties
